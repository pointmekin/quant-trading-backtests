# %%
import csv
import pandas as pd

# create a new dataframe from the csv file
def read_csv(file):
    df = pd.read_csv(file)
    # set ExitTime as the index
    df.set_index('ExitTime', inplace=True)
    return df


spx = read_csv('../spx.csv')
ndx = read_csv('../ndx.csv')

# %%
spx
# Out:
#                      Size  EntryBar  ExitBar   EntryPrice    ExitPrice  \
# ExitTime
# 2021-06-16 12:30:00    68        47       52  4249.100098  4237.830078
# 2021-06-16 12:30:00    70        42       52  4255.279785  4237.830078
# 2021-07-12 09:30:00    69        72      168  4215.069824  4376.647705
# 2021-07-19 10:30:00    69       128      204  4308.200195  4252.470215
# 2021-07-19 10:30:00    70       113      204  4297.160156  4252.470215
# ...                   ...       ...      ...          ...          ...
# 2024-01-16 14:30:00    89      4576     4583  4786.029785  4756.759766
# 2024-02-02 12:30:00    93      4594     4672  4758.850098  4959.110107
# 2024-03-25 11:30:00   105      4691     4916  4973.910156  5226.240234
# 2024-03-25 11:30:00    97      4647     4916  4904.770020  5226.240234
# 2024-03-25 11:30:00    95      4621     4916  4887.080078  5226.240234
#
#                               PnL  ReturnPct            EntryTime  Tag  \
# ExitTime
# ...

# %%
# # create a new df from spx and ndx's equity column
# def get_equity(spx, ndx):
#     equity = pd.concat([spx['equity'], ndx['equity']], axis=1)
#     equity.columns = ['spx', 'ndx']
#     return equity
  
# equity = get_equity(spx, ndx)

# equity["net"] = equity["ndx"] + equity["spx"]
# equity
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 7
#       4     equity.columns = ['spx', 'ndx']
#       5     return equity
# ----> 7 equity = get_equity(spx, ndx)
#       9 equity["net"] = equity["ndx"] + equity["spx"]
#      10 equity
#
# Cell In[42], line 3, in get_equity(spx, ndx)
#       2 def get_equity(spx, ndx):
# ----> 3     equity = pd.concat([spx['equity'], ndx['equity']], axis=1)
#       4     equity.columns = ['spx', 'ndx']
#       5     return equity
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/reshape/concat.py:393, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     378     copy = False
#     380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#    (...)
#     390     sort=sort,
#     391 )
# --> 393 return op.get_result()
#
# ...

# %%
# plot the equity
import matplotlib.pyplot as plt

# def plot_equity(equity):
#     # do not use the scientific notation 
#     equity.plot()
#     plt.show()
    
# plot_equity(equity)

# plot both df on the same plot
def plot_equity(spx, ndx):
    spx['equity'].plot()
    plt.show()
    
    # plot the sum
    ndx['equity'].plot()
    plt.show()
    
plot_equity(spx, ndx)
