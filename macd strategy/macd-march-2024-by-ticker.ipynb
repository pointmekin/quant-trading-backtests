# %%
import yfinance as yf
import pandas as pd
import pandas_ta as ta
import numpy as np
from backtesting import Strategy
from backtesting import Backtest
from sklearn.model_selection import ParameterGrid

# %%
def getYFinanceData(ticker, period, interval):
  dataF = yf.download(ticker, period=period, interval=interval)

  dataF.iloc[:,:]
  #dataF.Open.iloc

  df = pd.DataFrame(dataF)

  # use df index, convert DateTime to  a column instead of index
  df.reset_index(inplace=True)

  # delete Adj Close
  df = df.drop(['Adj Close'], axis=1)

  # rename Datetime to "Gmt time"
  df = df.rename(columns={'Datetime':'Gmt time'})
  
  # rename Date to "Gmt time"
  df = df.rename(columns={'Date':'Gmt time'})

  df['Gmt time']=pd.to_datetime(df['Gmt time'],format='%d.%m.%Y %H:%M:%S')
  df.set_index("Gmt time", inplace=True)
  df=df[df.High!=df.Low]

  return df

# %%
def calculateTechnicalAnalysis(df):
  df["MACD"]=ta.macd(df.Close)['MACD_12_26_9']
  df["MACD_HIST"]=ta.macd(df.Close)['MACDh_12_26_9']
  df["MACD_SIGNAL"]=ta.macd(df.Close)['MACDs_12_26_9']
  df['RSI']=ta.rsi(df.Close, length=16)
  return df

# %%
def getDataPair(ticker):
  df = getYFinanceData(ticker, "365d", "60m")
  df1d = getYFinanceData(ticker, "365d", "1d")
  
  df = calculateTechnicalAnalysis(df)
  df1d = calculateTechnicalAnalysis(df1d)
  
  # create the column called Date. its value is the index without the time
  df['Date'] = df.index.date
  df1d['Date'] = df1d.index.date
  
  # Ensure 'Date' in df and index in df1d are in the same datetime format
  df['Date'] = pd.to_datetime(df['Date'])
  df1d.index = pd.to_datetime(df1d.index)

  # Use a try/except block to handle missing dates
  def get_macd(row):
      try:
          return df1d.loc[row['Date']]['MACD']
      except KeyError:
          return np.nan
      
      
  def get_macd_hist(row):
      try:
          return df1d.loc[row['Date']]['MACD_HIST']
      except KeyError:
          return np.nan
      
  def get_macd_signal(row):
      try:
          return df1d.loc[row['Date']]['MACD_SIGNAL']
      except KeyError:
          return np.nan
      
  def get_adx(row):
      try:
          return df1d.loc[row['Date']]['ADX']
      except KeyError:
          return np.nan
      


  df['MACD_1d'] = df.apply(get_macd, axis=1)
  df['MACD_HIST_1d'] = df.apply(get_macd_hist, axis=1)
  df['MACD_SIGNAL_1d'] = df.apply(get_macd_signal, axis=1)
  df['ADX_1d'] = df.apply(get_adx, axis=1)
  return df

# %% [markdown]
# MACD Signal

# %%
def getMACDSignals(df):
  backcandles = 15
  # calcualte macd signal
  macd_signal = [0]*len(df)
  for row in range(1, len(df)):
      if(
          True
          and df.MACD_HIST[row-1] < 0 and df.MACD_HIST[row] > 0
      ):
          macd_signal[row]=1
      elif  (
          True
          and df.MACD_HIST[row-1] > 0 and df.MACD_HIST[row] < 0
      ):
          macd_signal[row]=-1

  df['MACDSignal'] = macd_signal
  return df

# %% [markdown]
# RSI Signal

# %%
def getRSISignals(df):
  backcandles = 14

  # calcualte macd signal
  rsi_signal = [0]*len(df)
  df.RSI_14MA = df.RSI
  for row in range(1, len(df)):
      if row < backcandles:
          continue

      if(
          True
          and df.RSI[row] > 50
          or (df.RSI[row]<25 and df.RSI[row-1]>25)

      ):
          rsi_signal[row]=1
      elif  (
          True
          and df.RSI[row] < 55
          or (df.RSI[row]>75 and df.RSI[row-1]<75)
      ):
          rsi_signal[row]=-1

  df['RSI_Signal'] = rsi_signal
  return df

# %% [markdown]
# Total Signal

# %%
def TotalSignal(df, l):
  if (
      df.MACDSignal[l]==1
      and df.RSI_Signal[l]==1
  ):
          return 2
  if (
      df.MACDSignal[l]==-1
      and df.RSI_Signal[l]==-1
  ):
          return 1
  return 0
      
def assignTotalSignal(df):
  backcandles= 14
  TotSignal = [0]*len(df)
  for row in range(backcandles, len(df)): #careful backcandles used previous cell
      TotSignal[row] = TotalSignal(df, row)
  df['TotalSignal'] = TotSignal
  return df

# %%
yfinance_dict = {}

def backtest(ticker, atr_length, init_size, tp_sl_ratio, slatr_coef):
    df = None
    if (ticker in yfinance_dict):
        df = yfinance_dict[ticker]
    else :
        df = getDataPair(ticker)
        df = getMACDSignals(df)
        df = getRSISignals(df)
        df = assignTotalSignal(df)
        yfinance_dict[ticker] = df
    
    dfpl = df.copy()
    import pandas_ta as ta
    dfpl['ATR']=ta.atr(dfpl.High, dfpl.Low, dfpl.Close, length=atr_length)
    #help(ta.atr)
    def SIGNAL():
        return dfpl.TotalSignal

    class MyStrat(Strategy):
        initsize = init_size
        mysize = initsize
        latestEntry = 0
        lastHigh = 0
        
        def init(self):
            super().init()
            self.signal1 = self.I(SIGNAL)

        def next(self):
            super().next()
            slatr = slatr_coef*self.data.ATR[-1]
            TPSLRatio = tp_sl_ratio
            
            # if the current equity is higher than lastHigh, then update lastHigh
            if (self.equity > self.lastHigh):
                self.lastHigh = self.equity
                
            # if self.position.pl is down for more than 2 percent of the height, close all positions
            if (self.position.pl < -1 * self.lastHigh * 0.02):
                self.position.close()
                # print("Close position due to loss")
                # print("------")
            
            # # close the position if the amount lost exceeds 3% of the account balance
            if (self.position.pl < -1 * self.equity * 0.02):
                self.position.close()
                # print("Close position due to loss")
                # print("------")

            if len(self.trades)>0:
                for trade in self.trades:
                    if trade.is_long and self.data.RSI[-1]>=90:
                        trade.close()
                    elif trade.is_short and self.data.RSI[-1]<=10:
                        trade.close()
                    
                    # update the stop loss to entry if the pl is greater than the stop loss amount
                    # if (trade.pl > self.equity * 0.01):
                    #     trade.sl = trade.entry_price
                    #     print("Update stop loss to entry")
                    #     print("------")
                    
                    # close the position if the amount lost exceeds 3% of the account balance
                    # if (trade.pl < -1 * self.equity * 0.01):
                    #     trade.close()
                    #     print("Close position due to loss")
                    #     print("------")
                    
            # # # if the pl is greater than the stop loss amount, then move the stop loss to entry
            # if (self.position.pl > self.latestEntry * 0.02):
            #     # adjust the stop loss to entry
            #     self.position.sl = self.latestEntry
            #     # # for each opened position, update the stop loss to the entry
            #     # for trade in self.trades:
            #     #     trade.sl = self.latestEntry
                    
                    
            
            # print("Datetime: ", self.data.index[-1])
            if self.signal1==2 and len(self.trades) < 3:
                sl1 = self.data.Close[-1] - slatr
                tp1 = self.data.Close[-1] + slatr*TPSLRatio
                self.buy(sl=sl1, tp=tp1, size=self.mysize)
                self.latestEntry = self.data.Close[-1]
                # print("Buy", self.data.Close[-1])
                # print("Stop loss: ", sl1)
                # print("Take profit: ", tp1)
                # print("------")
            
            elif self.signal1==1 and len(self.trades) < 1:         
                sl1 = self.data.Close[-1] + slatr
                tp1 = self.data.Close[-1] - slatr*TPSLRatio
                self.sell(sl=sl1, tp=tp1, size=self.mysize)
                self.latestEntry = self.data.Close[-1]
                # print("Sell", self.data.Close[-1])
                # print("Stop loss: ", sl1)
                # print("Take profit: ", tp1)
                # print("------")

            # else:
            #     print("No signal")

    bt = Backtest(dfpl, MyStrat, cash=100000, margin=1/100, commission=0)
    stat = bt.run()
    return stat, bt

# %% [markdown]
# ---

# %% [markdown]
# ## Optimize Draw Down

# %%
# use gridsearchcv to find the best parameters

# turn off printing
import sys
sys.stdout = open('output.txt', 'w')

# Define your custom estimator and scoring method
class MyCustomEstimator:
    def __init__(self, ticker, atr_length, init_size, tp_sl_ratio, slatr_coef):
        self.ticker = ticker
        self.atr_length = atr_length
        self.init_size = init_size
        self.tp_sl_ratio = tp_sl_ratio
        self.slatr_coef = slatr_coef

    def score(self):
        # Your scoring logic here
        stat, bt = backtest(self.ticker, atr_length=self.atr_length, init_size=self.init_size , tp_sl_ratio=self.tp_sl_ratio, slatr_coef=self.slatr_coef)
        return stat["Max. Drawdown [%]"]

# Create a grid of hyperparameters
param_grid = {
    'ticker': ["^NDX", "^SPX", "AAPL"],
    'atr_length': [1, 4, 8, 12, 16],
    'init_size': [0.02, 0.03],
    'tp_sl_ratio': [1.5, 2],
    'slatr_coef': [4, 9, 12],
}

parameters_df= []

# Iterate over all combinations
for params in ParameterGrid(param_grid):
    estimator = MyCustomEstimator(**params)
    score = estimator.score()
    # Compare scores and find the best combination
    parameters_df.append([params, score])

parameters_df
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3184709326.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] < 0 and df.MACD_HIST[row] > 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3184709326.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] > 0 and df.MACD_HIST[row] < 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.RSI_14MA = df.RSI
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] > 50
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]<25 and df.RSI[row-1]>25)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] < 55
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]>75 and df.RSI[row-1]<75)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3184709326.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] < 0 and df.MACD_HIST[row] > 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3184709326.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] > 0 and df.MACD_HIST[row] < 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.RSI_14MA = df.RSI
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] > 50
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]<25 and df.RSI[row-1]>25)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] < 55
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]>75 and df.RSI[row-1]<75)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 35
#      33 for params in ParameterGrid(param_grid):
#      34     estimator = MyCustomEstimator(**params)
# ---> 35     score = estimator.score()
#      36     # Compare scores and find the best combination
#      37     parameters_df.append([params, score])
#
# Cell In[36], line 18, in MyCustomEstimator.score(self)
#      16 def score(self):
#      17     # Your scoring logic here
# ---> 18     stat, bt = backtest(self.ticker, atr_length=self.atr_length, init_size=self.init_size , tp_sl_ratio=self.tp_sl_ratio, slatr_coef=self.slatr_coef)
#      19     return stat["Max. Drawdown [%]"]
#
# Cell In[35], line 8, in backtest(ticker, atr_length, init_size, tp_sl_ratio, slatr_coef)
#       6     df = yfinance_dict[ticker]
#       7 else :
# ----> 8     df = getDataPair(ticker)
#       9     df = getMACDSignals(df)
#      10     df = getRSISignals(df)
#
# Cell In[31], line 47, in getDataPair(ticker)
#      45 df['MACD_HIST_1d'] = df.apply(get_macd_hist, axis=1)
#      46 df['MACD_SIGNAL_1d'] = df.apply(get_macd_signal, axis=1)
# ---> 47 df['ADX_1d'] = df.apply(get_adx, axis=1)
#      48 return df
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:10034, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10022 from pandas.core.apply import frame_apply
#   10024 op = frame_apply(
#   10025     self,
#   10026     func=func,
#    (...)
#   10032     kwargs=kwargs,
#   10033 )
# > 10034 return op.apply().__finalize__(self, method="apply")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:965, in FrameApply.apply_standard(self)
#     964 def apply_standard(self):
# --> 965     results, res_index = self.apply_series_generator()
#     967     # wrap results
#     968     return self.wrap_results(results, res_index)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:981, in FrameApply.apply_series_generator(self)
#     978 with option_context("mode.chained_assignment", None):
#     979     for i, v in enumerate(series_gen):
#     980         # ignore SettingWithCopy here in case the user mutates
# --> 981         results[i] = self.func(v, *self.args, **self.kwargs)
#     982         if isinstance(results[i], ABCSeries):
#     983             # If we have a view on v, we need to make a copy because
#     984             #  series_generator will swap out the underlying data
#     985             results[i] = results[i].copy(deep=False)
#
# Cell In[31], line 38, in getDataPair.<locals>.get_adx(row)
#      36 def get_adx(row):
#      37     try:
# ---> 38         return df1d.loc[row['Date']]['ADX']
#      39     except KeyError:
#      40         return np.nan
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:4256, in NDFrame.xs(self, key, axis, level, drop_level)
#    4250 if self.ndim == 1:
#    4251     # if we encounter an array-like and we only have 1 dim
#    4252     # that means that their are list/ndarrays inside the Series!
#    4253     # so just return them (GH 6394)
#    4254     return self._values[loc]
# -> 4256 new_mgr = self._mgr.fast_xs(loc)
#    4258 result = self._constructor_sliced_from_mgr(new_mgr, axes=new_mgr.axes)
#    4259 result._name = self.index[loc]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/managers.py:941, in BlockManager.fast_xs(self, loc)
#     936     return cls(blocks, axes, verify_integrity=False)
#     938 # ----------------------------------------------------------------
#     939 # Indexing
# --> 941 def fast_xs(self, loc: int) -> SingleBlockManager:
#     942     """
#     943     Return the array corresponding to `frame.iloc[loc]`.
#     944
#    (...)
#     951     np.ndarray or ExtensionArray
#     952     """
#     953     if len(self.blocks) == 1:
#     954         # TODO: this could be wrong if blk.mgr_locs is not slice(None)-like;
#     955         #  is this ruled out in the general case?
#
# KeyboardInterrupt:

# %%
# find thee param tha resulted in the highest score
# max(parameters_df, key=lambda x: x[1])

ticker_groups = {}
for item in parameters_df:
    ticker = item[0]['ticker']
    if ticker not in ticker_groups:
        ticker_groups[ticker] = []
    ticker_groups[ticker].append(item)

# Find the item with the highest value in index 1 for each ticker
result = {}
for ticker, items in ticker_groups.items():
    max_item = max(items, key=lambda x: x[1])
    result[ticker] = max_item

result
# Out:
# {'^NDX': [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -30.44739452018299],
#  '^SPX': [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -26.469594857964495],
#  'AAPL': [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -32.35027169284598]}

# %%
stat, bt = backtest("^SPX", atr_length=8, init_size=0.03 , tp_sl_ratio=1.5, slatr_coef=4)
bt.plot()
stat
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_98550/69321050.py:2: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   bt.plot()
# Start                     2021-06-07 09:30:00
# End                       2024-03-25 15:30:00
# Duration                   1022 days 06:00:00
# Exposure Time [%]                   61.755741
# Equity Final [$]                428537.708578
# Equity Peak [$]                  436452.46102
# Return [%]                         328.537709
# Buy & Hold Return [%]               23.757138
# Return (Ann.) [%]                   68.229621
# Volatility (Ann.) [%]               84.192396
# Sharpe Ratio                         0.810401
# Sortino Ratio                        2.458891
# Calmar Ratio                         2.177822
# Max. Drawdown [%]                  -31.329297
# Avg. Drawdown [%]                   -4.153057
# Max. Drawdown Duration      316 days 21:00:00
# Avg. Drawdown Duration       12 days 00:00:00
# # Trades                                  158
# Win Rate [%]                        36.708861
# Best Trade [%]                       7.058676
# Worst Trade [%]                     -3.749627
# Avg. Trade [%]                       0.328916
# Max. Trade Duration          36 days 00:00:00
# Avg. Trade Duration           5 days 09:00:00
# Profit Factor                        1.607528
# Expectancy [%]                       0.347154
# SQN                                  2.927546
# Kelly Criterion                      0.178166
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %%
stat, bt = backtest("^NDX", atr_length=1, init_size=0.02 , tp_sl_ratio=2, slatr_coef=4)
bt.plot()
stat
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_98550/1630965305.py:2: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   bt.plot()
# Start                     2021-04-30 09:30:00
# End                       2024-03-25 15:30:00
# Duration                   1060 days 06:00:00
# Exposure Time [%]                    69.76607
# Equity Final [$]                535038.649414
# Equity Peak [$]                 692238.485352
# Return [%]                         435.038649
# Buy & Hold Return [%]               31.071478
# Return (Ann.) [%]                    78.56135
# Volatility (Ann.) [%]                90.42001
# Sharpe Ratio                         0.868849
# Sortino Ratio                        2.772082
# Calmar Ratio                         2.580232
# Max. Drawdown [%]                  -30.447395
# Avg. Drawdown [%]                    -2.86957
# Max. Drawdown Duration      266 days 02:00:00
# Avg. Drawdown Duration        8 days 12:00:00
# # Trades                                  143
# Win Rate [%]                        37.062937
# Best Trade [%]                      13.674375
# Worst Trade [%]                     -4.340308
# Avg. Trade [%]                       0.795216
# Max. Trade Duration          97 days 23:00:00
# Avg. Trade Duration           8 days 03:00:00
# Profit Factor                        2.069664
# Expectancy [%]                       0.854606
# SQN                                  1.696014
# Kelly Criterion                      0.126982
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %% [markdown]
# ## Optimize Win Rate

# %%
# use gridsearchcv to find the best parameters

# turn off printing
import sys
sys.stdout = open('output.txt', 'w')

# Define your custom estimator and scoring method
class MyCustomEstimator:
    def __init__(self, ticker, atr_length, init_size, tp_sl_ratio, slatr_coef):
        self.ticker = ticker
        self.atr_length = atr_length
        self.init_size = init_size
        self.tp_sl_ratio = tp_sl_ratio
        self.slatr_coef = slatr_coef

    def score(self):
        # Your scoring logic here
        stat, bt = backtest(self.ticker, atr_length=self.atr_length, init_size=self.init_size , tp_sl_ratio=self.tp_sl_ratio, slatr_coef=self.slatr_coef)
        return stat["Win Rate [%]"]

# Create a grid of hyperparameters
param_grid = {
    'ticker': ["^NDX", "^SPX", "AAPL"],
    'atr_length': [1, 4, 8, 12, 16],
    'init_size': [0.02, 0.03],
    'tp_sl_ratio': [1.5, 2],
    'slatr_coef': [4, 9, 12],
}

parameters_df= []

# Iterate over all combinations
for params in ParameterGrid(param_grid):
    estimator = MyCustomEstimator(**params)
    score = estimator.score()
    # Compare scores and find the best combination
    parameters_df.append([params, score])

parameters_df
# Out:
# [[{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   36.774193548387096],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   37.06293706293706],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   41.17647058823529],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   33.88429752066116],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   43.53741496598639],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   38.732394366197184],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   45.88235294117647],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   42.1875],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   33.734939759036145],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   27.27272727272727],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   39.37007874015748],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   34.51327433628318],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   43.07692307692308],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   38.18181818181819],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   26.923076923076923],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   24.528301886792452],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   33.6283185840708],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   35.64356435643564],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   35.58282208588957],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   35.714285714285715],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   41.66666666666667],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   33.08270676691729],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   35.714285714285715],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   33.108108108108105],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   38.095238095238095],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   35.44303797468354],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   32.69230769230769],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.95454545454545],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   33.82352941176471],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   31.092436974789916],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   36.58536585365854],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   37.878787878787875],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   33.65384615384615],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.883720930232556],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   31.092436974789916],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   29.591836734693878],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   34.161490683229815],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   34.69387755102041],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   39.189189189189186],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   37.2093023255814],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   36.477987421383645],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   34.72222222222222],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   34.12698412698413],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   42.42424242424242],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   43.29896907216495],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.05128205128205],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   36.52173913043478],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   34.862385321100916],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   40.816326530612244],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   31.645569620253166],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   38.2716049382716],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.91139240506329],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   35.77981651376147],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   36.36363636363637],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   31.952662721893493],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   32.91139240506329],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   36.30573248407643],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.78260869565217],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   29.34131736526946],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   31.125827814569533],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   28.368794326241137],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   37.83783783783784],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   40.909090909090914],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.95145631067961],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   34.146341463414636],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   28.205128205128204],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   38.18181818181819],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   39.75903614457831],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   36.0],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.04255319148936],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   29.059829059829063],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   35.55555555555556],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   34.33734939759036],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   32.89473684210527],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   40.0],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   41.66666666666667],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   36.41975308641975],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   32.86713286713287],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   32.55813953488372],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   34.82142857142857],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   44.89795918367347],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   33.734939759036145],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   37.5],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   34.25925925925926],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   34.82142857142857],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   34.02061855670103],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   37.07865168539326],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.91139240506329],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   35.18518518518518],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   40.0],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   31.213872832369944],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   29.518072289156628],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   36.708860759493675],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   35.41666666666667],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   29.411764705882355],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   30.065359477124183],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   28.671328671328673],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   29.03225806451613],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   41.81818181818181],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   36.84210526315789],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   32.30769230769231],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   29.059829059829063],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   29.03225806451613],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   31.06796116504854],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   36.0],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.608695652173914],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   29.914529914529915],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   32.71028037383177],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   34.54545454545455],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   31.818181818181817],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   38.25503355704698],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   39.55223880597015],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   37.423312883435585],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   33.56643356643357],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   33.59375],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   40.54054054054054],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   46.875],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   35.22727272727273],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   38.13559322033898],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   33.94495412844037],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   35.65217391304348],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   34.883720930232556],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   37.634408602150536],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.91139240506329],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   33.94495412844037],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   38.88888888888889],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   32.369942196531795],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   28.74251497005988],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   35.03184713375796],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   33.793103448275865],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   30.76923076923077],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   29.411764705882355],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   27.659574468085108],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   35.77235772357724],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   40.36697247706422],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.69387755102041],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   31.538461538461537],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   29.66101694915254],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   30.075187969924812],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   35.55555555555556],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   35.0],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.608695652173914],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   29.66101694915254],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   32.71028037383177],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   35.75757575757576],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   31.61290322580645],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   38.56209150326798],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   39.55223880597015],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   37.03703703703704],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   34.96503496503497],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   32.08955223880597],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   38.93805309734513],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   40.5940594059406],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   42.5],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   38.13559322033898],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   34.25925925925926],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   36.84210526315789],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   32.98969072164948],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   41.46341463414634],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   33.75],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   34.25925925925926],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   40.0],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   33.33333333333333],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   27.647058823529413],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   35.625],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.02777777777778],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   30.17751479289941],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   30.32258064516129],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   28.27586206896552],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   29.770992366412212],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   40.74074074074074],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.69387755102041],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   30.76923076923077],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   29.914529914529915],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   29.770992366412212],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   32.407407407407405],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   35.78947368421053],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.608695652173914],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   29.914529914529915],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   32.71028037383177]]

# %%
# find thee param tha resulted in the highest score
# max(parameters_df, key=lambda x: x[1])

ticker_groups = {}
for item in parameters_df:
    ticker = item[0]['ticker']
    if ticker not in ticker_groups:
        ticker_groups[ticker] = []
    ticker_groups[ticker].append(item)

# Find the item with the highest value in index 1 for each ticker
result = {}
for ticker, items in ticker_groups.items():
    max_item = max(items, key=lambda x: x[1])
    result[ticker] = max_item

result
# Out:
# {'^NDX': [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   45.88235294117647],
#  '^SPX': [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   46.875],
#  'AAPL': [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   43.53741496598639]}

# %%
stat, bt = backtest("^SPX", atr_length=12, init_size=0.02 , tp_sl_ratio=1.5, slatr_coef=9)
bt.plot()
stat
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_98550/805540974.py:2: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   bt.plot()
# Start                     2021-06-07 09:30:00
# End                       2024-03-25 15:30:00
# Duration                   1022 days 06:00:00
# Exposure Time [%]                   83.743142
# Equity Final [$]                382046.856494
# Equity Peak [$]                 396626.663622
# Return [%]                         282.046856
# Buy & Hold Return [%]               23.757138
# Return (Ann.) [%]                   61.464009
# Volatility (Ann.) [%]                 74.7289
# Sharpe Ratio                         0.822493
# Sortino Ratio                        2.163558
# Calmar Ratio                         2.098224
# Max. Drawdown [%]                  -29.293348
# Avg. Drawdown [%]                   -3.424864
# Max. Drawdown Duration      338 days 01:00:00
# Avg. Drawdown Duration       10 days 12:00:00
# # Trades                                   96
# Win Rate [%]                           46.875
# Best Trade [%]                       9.191412
# Worst Trade [%]                      -3.24026
# Avg. Trade [%]                         1.0866
# Max. Trade Duration          77 days 23:00:00
# Avg. Trade Duration          16 days 18:00:00
# Profit Factor                         2.66943
# Expectancy [%]                        1.13545
# SQN                                  3.368453
# Kelly Criterion                      0.307558
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
stat, bt = backtest("^NDX", atr_length=1, init_size=0.02 , tp_sl_ratio=1.5, slatr_coef=9)
bt.plot()
stat
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_98550/2712909604.py:2: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   bt.plot()
# Start                     2021-04-30 09:30:00
# End                       2024-03-25 15:30:00
# Duration                   1060 days 06:00:00
# Exposure Time [%]                   83.801848
# Equity Final [$]                 783631.88916
# Equity Peak [$]                  804194.38916
# Return [%]                         683.631889
# Buy & Hold Return [%]               31.071478
# Return (Ann.) [%]                  103.739759
# Volatility (Ann.) [%]              139.254638
# Sharpe Ratio                         0.744964
# Sortino Ratio                        2.644954
# Calmar Ratio                         2.187322
# Max. Drawdown [%]                  -47.427741
# Avg. Drawdown [%]                   -3.874711
# Max. Drawdown Duration      323 days 00:00:00
# Avg. Drawdown Duration        8 days 15:00:00
# # Trades                                   85
# Win Rate [%]                        45.882353
# Best Trade [%]                       21.26462
# Worst Trade [%]                     -9.698482
# Avg. Trade [%]                       1.533257
# Max. Trade Duration         231 days 00:00:00
# Avg. Trade Duration          21 days 17:00:00
# Profit Factor                        2.570762
# Expectancy [%]                       1.679956
# SQN                                  2.737211
# Kelly Criterion                      0.303605
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %% [markdown]
# ## Higheest return

# %%
stat2, bt2 = backtest("^NDX", atr_length=1, init_size=0.02 , tp_sl_ratio=2, slatr_coef=4)
bt.plot(show_legend=False)
stat2
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_98550/41808923.py:2: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   bt.plot(show_legend=False)
# Start                     2021-04-30 09:30:00
# End                       2024-03-25 15:30:00
# Duration                   1060 days 06:00:00
# Exposure Time [%]                    69.76607
# Equity Final [$]                535038.649414
# Equity Peak [$]                 692238.485352
# Return [%]                         435.038649
# Buy & Hold Return [%]               31.071478
# Return (Ann.) [%]                    78.56135
# Volatility (Ann.) [%]                90.42001
# Sharpe Ratio                         0.868849
# Sortino Ratio                        2.772082
# Calmar Ratio                         2.580232
# Max. Drawdown [%]                  -30.447395
# Avg. Drawdown [%]                    -2.86957
# Max. Drawdown Duration      266 days 02:00:00
# Avg. Drawdown Duration        8 days 12:00:00
# # Trades                                  143
# Win Rate [%]                        37.062937
# Best Trade [%]                      13.674375
# Worst Trade [%]                     -4.340308
# Avg. Trade [%]                       0.795216
# Max. Trade Duration          97 days 23:00:00
# Avg. Trade Duration           8 days 03:00:00
# Profit Factor                        2.069664
# Expectancy [%]                       0.854606
# SQN                                  1.696014
# Kelly Criterion                      0.126982
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %%
stat, bt = backtest("^NDX", atr_length=1, init_size=0.03 , tp_sl_ratio=1.5, slatr_coef=9)
bt.plot()
stat
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3184709326.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] < 0 and df.MACD_HIST[row] > 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3184709326.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] > 0 and df.MACD_HIST[row] < 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.RSI_14MA = df.RSI
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] > 50
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]<25 and df.RSI[row-1]>25)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] < 55
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]>75 and df.RSI[row-1]<75)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/519562990.py:2: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   bt.plot()
# Start                     2021-04-30 09:30:00
# End                       2024-03-25 15:30:00
# Duration                   1060 days 06:00:00
# Exposure Time [%]                    77.35404
# Equity Final [$]               1691187.258789
# Equity Peak [$]                1750078.258789
# Return [%]                        1591.187259
# Buy & Hold Return [%]               30.950097
# Return (Ann.) [%]                  165.803131
# Volatility (Ann.) [%]              244.395504
# Sharpe Ratio                         0.678421
# Sortino Ratio                        3.462615
# Calmar Ratio                         3.541719
# Max. Drawdown [%]                  -46.814307
# Avg. Drawdown [%]                   -5.892652
# Max. Drawdown Duration      262 days 00:00:00
# Avg. Drawdown Duration        9 days 06:00:00
# # Trades                                  105
# Win Rate [%]                        38.095238
# Best Trade [%]                       21.26462
# Worst Trade [%]                      -5.53113
# Avg. Trade [%]                       1.229796
# Max. Trade Duration         170 days 23:00:00
# Avg. Trade Duration          15 days 09:00:00
# Profit Factor                        2.475103
# Expectancy [%]                       1.344147
# SQN                                  2.460499
# Kelly Criterion                       0.24011
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %%
stat, bt = backtest("BTC-USD", atr_length=1, init_size=0.03 , tp_sl_ratio=1.5, slatr_coef=1)
bt.plot()
stat
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3184709326.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] < 0 and df.MACD_HIST[row] > 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3184709326.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] > 0 and df.MACD_HIST[row] < 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.RSI_14MA = df.RSI
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] > 50
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]<25 and df.RSI[row-1]>25)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] < 55
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3003789530.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]>75 and df.RSI[row-1]<75)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_13884/3560849306.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==1
# Start                     2023-03-28 00:00:00
# End                       2024-03-26 06:00:00
# Duration                    364 days 06:00:00
# Exposure Time [%]                   27.419355
# Equity Final [$]                 73432.873047
# Equity Peak [$]                 102412.382812
# Return [%]                         -26.567127
# Buy & Hold Return [%]              160.945806
# Return (Ann.) [%]                  -26.567127
# Volatility (Ann.) [%]               39.199883
# Sharpe Ratio                        -0.677735
# Sortino Ratio                       -0.758648
# Calmar Ratio                        -0.693006
# Max. Drawdown [%]                   -38.33606
# Avg. Drawdown [%]                  -13.997725
# Max. Drawdown Duration      360 days 05:00:00
# Avg. Drawdown Duration      120 days 06:00:00
# # Trades                                  362
# Win Rate [%]                        36.187845
# Best Trade [%]                       3.621713
# Worst Trade [%]                     -2.766611
# Avg. Trade [%]                       -0.02187
# Max. Trade Duration           2 days 08:00:00
# Avg. Trade Duration           0 days 06:00:00
# Profit Factor                        0.954509
# Expectancy [%]                      -0.017412
# SQN                                 -0.660982
# Kelly Criterion                     -0.033719
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
