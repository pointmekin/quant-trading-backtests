# %%
import yfinance as yf
import pandas as pd
import pandas_ta as ta
import numpy as np
from backtesting import Strategy
from backtesting import Backtest
from sklearn.model_selection import ParameterGrid

# %%
def getYFinanceData(ticker, period, interval):
  dataF = yf.download(ticker, period=period, interval=interval)

  dataF.iloc[:,:]
  #dataF.Open.iloc

  df = pd.DataFrame(dataF)

  # use df index, convert DateTime to  a column instead of index
  df.reset_index(inplace=True)

  # delete Adj Close
  df = df.drop(['Adj Close'], axis=1)

  # rename Datetime to "Gmt time"
  df = df.rename(columns={'Datetime':'Gmt time'})
  
  # rename Date to "Gmt time"
  df = df.rename(columns={'Date':'Gmt time'})

  df['Gmt time']=pd.to_datetime(df['Gmt time'],format='%d.%m.%Y %H:%M:%S')
  df.set_index("Gmt time", inplace=True)
  df=df[df.High!=df.Low]

  return df

# %%
def calculateTechnicalAnalysis(df):
  df["MACD"]=ta.macd(df.Close)['MACD_12_26_9']
  df["MACD_HIST"]=ta.macd(df.Close)['MACDh_12_26_9']
  df["MACD_SIGNAL"]=ta.macd(df.Close)['MACDs_12_26_9']
  df['RSI']=ta.rsi(df.Close, length=16)
  return df

# %%
def getDataPair(ticker):
  df = getYFinanceData(ticker, "730d", "60m")
  df1d = getYFinanceData(ticker, "730d", "1d")
  
  df = calculateTechnicalAnalysis(df)
  df1d = calculateTechnicalAnalysis(df1d)
  
  # create the column called Date. its value is the index without the time
  df['Date'] = df.index.date
  df1d['Date'] = df1d.index.date
  
  # Ensure 'Date' in df and index in df1d are in the same datetime format
  df['Date'] = pd.to_datetime(df['Date'])
  df1d.index = pd.to_datetime(df1d.index)

  # Use a try/except block to handle missing dates
  def get_macd(row):
      try:
          return df1d.loc[row['Date']]['MACD']
      except KeyError:
          return np.nan
      
      
  def get_macd_hist(row):
      try:
          return df1d.loc[row['Date']]['MACD_HIST']
      except KeyError:
          return np.nan
      
  def get_macd_signal(row):
      try:
          return df1d.loc[row['Date']]['MACD_SIGNAL']
      except KeyError:
          return np.nan
      
  def get_adx(row):
      try:
          return df1d.loc[row['Date']]['ADX']
      except KeyError:
          return np.nan
      


  df['MACD_1d'] = df.apply(get_macd, axis=1)
  df['MACD_HIST_1d'] = df.apply(get_macd_hist, axis=1)
  df['MACD_SIGNAL_1d'] = df.apply(get_macd_signal, axis=1)
  df['ADX_1d'] = df.apply(get_adx, axis=1)
  return df

# %% [markdown]
# MACD Signal

# %%
def getMACDSignals(df):
  backcandles = 15
  # calcualte macd signal
  macd_signal = [0]*len(df)
  for row in range(1, len(df)):
      if(
          True
          and df.MACD_HIST[row-1] < 0 and df.MACD_HIST[row] > 0
      ):
          macd_signal[row]=1
      elif  (
          True
          and df.MACD_HIST[row-1] > 0 and df.MACD_HIST[row] < 0
      ):
          macd_signal[row]=-1

  df['MACDSignal'] = macd_signal
  return df

# %% [markdown]
# RSI Signal

# %%
def getRSISignals(df):
  backcandles = 14

  # calcualte macd signal
  rsi_signal = [0]*len(df)
  df.RSI_14MA = df.RSI
  for row in range(1, len(df)):
      if row < backcandles:
          continue

      if(
          True
          and df.RSI[row] > 50
          or (df.RSI[row]<25 and df.RSI[row-1]>25)

      ):
          rsi_signal[row]=1
      elif  (
          True
          and df.RSI[row] < 55
          or (df.RSI[row]>75 and df.RSI[row-1]<75)
      ):
          rsi_signal[row]=-1

  df['RSI_Signal'] = rsi_signal
  return df

# %% [markdown]
# Total Signal

# %%
def TotalSignal(df, l):
  if (
      df.MACDSignal[l]==1
      and df.RSI_Signal[l]==1
  ):
          return 2
  if (
      df.MACDSignal[l]==-1
      and df.RSI_Signal[l]==-1
  ):
          return 1
  return 0
      
def assignTotalSignal(df):
  backcandles= 14
  TotSignal = [0]*len(df)
  for row in range(backcandles, len(df)): #careful backcandles used previous cell
      TotSignal[row] = TotalSignal(df, row)
  df['TotalSignal'] = TotSignal
  return df

# %%
yfinance_dict = {}

def backtest(ticker, atr_length, init_size, tp_sl_ratio, slatr_coef):
    df = None
    if (ticker in yfinance_dict):
        df = yfinance_dict[ticker]
    else :
        df = getDataPair(ticker)
        df = getMACDSignals(df)
        df = getRSISignals(df)
        df = assignTotalSignal(df)
        yfinance_dict[ticker] = df
    
    dfpl = df.copy()
    import pandas_ta as ta
    dfpl['ATR']=ta.atr(dfpl.High, dfpl.Low, dfpl.Close, length=atr_length)
    #help(ta.atr)
    def SIGNAL():
        return dfpl.TotalSignal

    class MyStrat(Strategy):
        initsize = init_size
        mysize = initsize
        latestEntry = 0
        lastHigh = 0
        
        def init(self):
            super().init()
            self.signal1 = self.I(SIGNAL)

        def next(self):
            super().next()
            slatr = slatr_coef*self.data.ATR[-1]
            TPSLRatio = tp_sl_ratio
            
            # if the current equity is higher than lastHigh, then update lastHigh
            if (self.equity > self.lastHigh):
                self.lastHigh = self.equity
                
            # if self.position.pl is down for more than 2 percent of the height, close all positions
            if (self.position.pl < -1 * self.lastHigh * 0.02):
                self.position.close()
                # print("Close position due to loss")
                # print("------")
            
            # # close the position if the amount lost exceeds 3% of the account balance
            if (self.position.pl < -1 * self.equity * 0.02):
                self.position.close()
                # print("Close position due to loss")
                # print("------")

            if len(self.trades)>0:
                for trade in self.trades:
                    if trade.is_long and self.data.RSI[-1]>=90:
                        trade.close()
                    elif trade.is_short and self.data.RSI[-1]<=10:
                        trade.close()
                    
                    # update the stop loss to entry if the pl is greater than the stop loss amount
                    # if (trade.pl > self.equity * 0.01):
                    #     trade.sl = trade.entry_price
                    #     print("Update stop loss to entry")
                    #     print("------")
                    
                    # close the position if the amount lost exceeds 3% of the account balance
                    # if (trade.pl < -1 * self.equity * 0.01):
                    #     trade.close()
                    #     print("Close position due to loss")
                    #     print("------")
                    
            # # # if the pl is greater than the stop loss amount, then move the stop loss to entry
            # if (self.position.pl > self.latestEntry * 0.02):
            #     # adjust the stop loss to entry
            #     self.position.sl = self.latestEntry
            #     # # for each opened position, update the stop loss to the entry
            #     # for trade in self.trades:
            #     #     trade.sl = self.latestEntry
                    
                    
            
            # print("Datetime: ", self.data.index[-1])
            if self.signal1==2 and len(self.trades) < 3:
                sl1 = self.data.Close[-1] - slatr
                tp1 = self.data.Close[-1] + slatr*TPSLRatio
                self.buy(sl=sl1, tp=tp1, size=self.mysize)
                self.latestEntry = self.data.Close[-1]
                # print("Buy", self.data.Close[-1])
                # print("Stop loss: ", sl1)
                # print("Take profit: ", tp1)
                # print("------")
            
            elif self.signal1==1 and len(self.trades) < 1:         
                sl1 = self.data.Close[-1] + slatr
                tp1 = self.data.Close[-1] - slatr*TPSLRatio
                self.sell(sl=sl1, tp=tp1, size=self.mysize)
                self.latestEntry = self.data.Close[-1]
                # print("Sell", self.data.Close[-1])
                # print("Stop loss: ", sl1)
                # print("Take profit: ", tp1)
                # print("------")

            # else:
            #     print("No signal")

    bt = Backtest(dfpl, MyStrat, cash=100000, margin=1/100, commission=0)
    stat = bt.run()
    return stat, bt

# %% [markdown]
# ---

# %% [markdown]
# ## Optimize Draw Down

# %%
# use gridsearchcv to find the best parameters

# turn off printing
import sys
sys.stdout = open('output.txt', 'w')

# Define your custom estimator and scoring method
class MyCustomEstimator:
    def __init__(self, ticker, atr_length, init_size, tp_sl_ratio, slatr_coef):
        self.ticker = ticker
        self.atr_length = atr_length
        self.init_size = init_size
        self.tp_sl_ratio = tp_sl_ratio
        self.slatr_coef = slatr_coef

    def score(self):
        # Your scoring logic here
        stat, bt = backtest(self.ticker, atr_length=self.atr_length, init_size=self.init_size , tp_sl_ratio=self.tp_sl_ratio, slatr_coef=self.slatr_coef)
        return stat["Max. Drawdown [%]"]

# Create a grid of hyperparameters
param_grid = {
    'ticker': ["^NDX", "^SPX", "AAPL"],
    'atr_length': [1, 4, 8, 12, 16],
    'init_size': [0.02, 0.03],
    'tp_sl_ratio': [1.5, 2],
    'slatr_coef': [4, 9, 12],
}

parameters_df= []

# Iterate over all combinations
for params in ParameterGrid(param_grid):
    estimator = MyCustomEstimator(**params)
    score = estimator.score()
    # Compare scores and find the best combination
    parameters_df.append([params, score])

parameters_df
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3184709326.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] < 0 and df.MACD_HIST[row] > 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3184709326.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] > 0 and df.MACD_HIST[row] < 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.RSI_14MA = df.RSI
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] > 50
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]<25 and df.RSI[row-1]>25)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] < 55
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]>75 and df.RSI[row-1]<75)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3893405601.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3893405601.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3893405601.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3893405601.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3184709326.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] < 0 and df.MACD_HIST[row] > 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3184709326.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] > 0 and df.MACD_HIST[row] < 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.RSI_14MA = df.RSI
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] > 50
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]<25 and df.RSI[row-1]>25)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] < 55
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]>75 and df.RSI[row-1]<75)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3893405601.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3893405601.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3893405601.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3893405601.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==1
# [[{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -31.18394032445091],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -30.44739452018299],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -34.16920308170492],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -36.17004402085594],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -33.490283424926304],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -37.506748253583474],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -47.427741307720225],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -61.85564093797049],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -49.33998188409199],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -48.116807309117114],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -43.07378418922515],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -61.60696898355711],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -62.101753546849615],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -72.93081290070691],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -47.60419918446791],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -43.61048298718525],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -61.535863396426784],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -65.79635628237298],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -40.724603310429764],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -43.369102665214456],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -31.931182301044693],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -42.32243502663899],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -54.666989789717256],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -56.83540133645394],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -46.814306632926375],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -57.767185104642785],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -42.88896806897359],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -46.983861904498845],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -57.74753778013629],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -69.63829803023643],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -57.313170656523184],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -70.20904549827667],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -47.09141985196095],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -49.85842927670685],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -65.1666594287747],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -75.66291513660164],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -46.494957562942],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -45.21130245807263],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -33.7792620462561],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -42.30941203892089],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -32.35027169284598],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -60.47841481510219],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -40.3733733819164],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -44.175219028029844],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -31.31495288718633],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -55.223319419352215],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -61.534908771589855],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -53.27627305192919],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -50.17800446981538],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -59.063009018693435],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -37.96958579159641],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -49.33961333316521],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -53.275632893176784],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -65.18522541261413],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -57.817493638276815],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -55.01917594188439],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -29.71213505210587],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -34.08903956833701],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -53.42226422013396],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -53.4198286663472],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -56.65263119930849],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -51.90971946234257],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -47.12914506026943],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -56.12214662825231],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -56.05583687226247],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -72.2178936931647],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -51.90971946234257],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -66.13124232336351],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -50.5743630849872],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -59.26392377013507],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -72.2190172989482],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -70.99675935844164],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -46.0518020784214],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -42.7472271700302],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -26.469594857964495],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -39.2971068410852],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -39.190795311894014],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -60.85997519207923],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -38.099462920313385],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -45.367257961822624],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -32.595638090073855],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -59.493911860749904],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -42.96874834812646],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -61.537063836308434],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -45.52723453256298],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -55.91821035214915],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -45.003193261424435],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -49.303336442315256],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -61.53642620833113],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -65.77132577479914],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -60.87270699827316],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -61.68404190641088],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -31.329297179032444],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -33.28895554050485],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -57.176937186525414],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -77.84840317918511],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -52.24284862416943],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -48.66080062358521],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -47.99634580080125],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -52.94188304045535],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -59.456043083520214],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -70.87649039297663],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -48.66080062358521],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -66.02366118370628],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -56.13550163928824],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -59.294598011040186],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -70.87618644554483],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -74.47592752903502],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -46.19410504760132],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -46.53349695398853],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -30.23368336706621],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -44.680878587111636],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -39.315002946091695],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -60.91477425282249],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -37.4983631459173],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -43.27529575703264],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -29.29334812067421],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -55.2417727595476],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -42.96937571007964],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -61.53501952288043],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -43.86450274473963],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -55.912434254993215],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -40.80444191249612],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -49.28947090526914],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -61.5375594103252],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -65.77201893887134],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -61.70821791612744],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -60.69391128210331],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -35.1010554139062],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -38.0783822356341],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -59.16438467795806],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -76.55821592731326],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -53.72876062299166],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -51.61477369086837],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -39.06040650641343],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -53.48029548729936],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -60.17052391259],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -70.87586845458766],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -51.61477369086837],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -66.03538158326181],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -53.27890235245319],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -62.57950793654683],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -70.87586845458766],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -74.47346668586786],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -47.67484688190484],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -43.171661085508184],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -30.535833694518832],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -42.03225316551741],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -39.6693776332543],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -51.49027532008574],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -38.66221579334365],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -43.74775377341632],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -40.35373838085676],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -46.44136726756272],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -42.96735460809046],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -61.5364970732444],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -41.48288577560086],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -56.1231649097262],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -39.528391282883526],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -37.49504675510402],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -61.53497591783263],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -65.77163000968854],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -60.862167965489455],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -60.51473034901226],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -33.370564159162974],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -37.1297484832698],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -60.165029734245444],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -54.55872127690722],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -52.20173003434174],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -51.68370330682481],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -38.31351161031002],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -60.83212433576455],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -60.45927267597124],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -70.87584251031763],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   -51.68370330682481],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -66.05677859244534],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -56.72785458483849],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   -62.618049598119285],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -70.87584251031763],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   -74.47461270058243]]

# %%
# find thee param tha resulted in the highest score
# max(parameters_df, key=lambda x: x[1])

ticker_groups = {}
for item in parameters_df:
    ticker = item[0]['ticker']
    if ticker not in ticker_groups:
        ticker_groups[ticker] = []
    ticker_groups[ticker].append(item)

# Find the item with the highest value in index 1 for each ticker
result = {}
for ticker, items in ticker_groups.items():
    max_item = max(items, key=lambda x: x[1])
    result[ticker] = max_item

result
# Out:
# {'^NDX': [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   -30.44739452018299],
#  '^SPX': [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   -26.469594857964495],
#  'AAPL': [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   -32.35027169284598]}

# %%
stat, bt = backtest("^SPX", atr_length=8, init_size=0.03 , tp_sl_ratio=1.5, slatr_coef=4)
bt.plot()
stat
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/69321050.py:2: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   bt.plot()
# Start                     2021-06-07 09:30:00
# End                       2024-03-25 13:30:00
# Duration                   1022 days 04:00:00
# Exposure Time [%]                   61.740191
# Equity Final [$]                429122.867758
# Equity Peak [$]                  436452.46102
# Return [%]                         329.122868
# Buy & Hold Return [%]               23.857585
# Return (Ann.) [%]                   68.311696
# Volatility (Ann.) [%]               84.231752
# Sharpe Ratio                         0.810997
# Sortino Ratio                        2.461927
# Calmar Ratio                         2.180441
# Max. Drawdown [%]                  -31.329297
# Avg. Drawdown [%]                   -4.151761
# Max. Drawdown Duration      316 days 21:00:00
# Avg. Drawdown Duration       12 days 00:00:00
# # Trades                                  158
# Win Rate [%]                        36.708861
# Best Trade [%]                       7.058676
# Worst Trade [%]                     -3.749627
# Avg. Trade [%]                       0.329256
# Max. Trade Duration          36 days 00:00:00
# Avg. Trade Duration           5 days 09:00:00
# Profit Factor                        1.608128
# Expectancy [%]                       0.347497
# SQN                                   2.93138
# Kelly Criterion                      0.178329
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %%
stat, bt = backtest("^NDX", atr_length=1, init_size=0.02 , tp_sl_ratio=2, slatr_coef=4)
bt.plot()
stat
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/1630965305.py:2: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   bt.plot()
# Start                     2021-04-30 09:30:00
# End                       2024-03-25 14:30:00
# Duration                   1060 days 05:00:00
# Exposure Time [%]                   69.779788
# Equity Final [$]                535038.649414
# Equity Peak [$]                 692238.485352
# Return [%]                         435.038649
# Buy & Hold Return [%]               31.297349
# Return (Ann.) [%]                    78.56135
# Volatility (Ann.) [%]                90.42001
# Sharpe Ratio                         0.868849
# Sortino Ratio                        2.772082
# Calmar Ratio                         2.580232
# Max. Drawdown [%]                  -30.447395
# Avg. Drawdown [%]                    -2.86957
# Max. Drawdown Duration      266 days 02:00:00
# Avg. Drawdown Duration        8 days 12:00:00
# # Trades                                  143
# Win Rate [%]                        37.062937
# Best Trade [%]                      13.674375
# Worst Trade [%]                     -4.340308
# Avg. Trade [%]                       0.795216
# Max. Trade Duration          97 days 23:00:00
# Avg. Trade Duration           8 days 03:00:00
# Profit Factor                        2.069664
# Expectancy [%]                       0.854606
# SQN                                  1.696014
# Kelly Criterion                      0.126982
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %% [markdown]
# ## Optimize Win Rate

# %%
# use gridsearchcv to find the best parameters

# turn off printing
import sys
sys.stdout = open('output.txt', 'w')

# Define your custom estimator and scoring method
class MyCustomEstimator:
    def __init__(self, ticker, atr_length, init_size, tp_sl_ratio, slatr_coef):
        self.ticker = ticker
        self.atr_length = atr_length
        self.init_size = init_size
        self.tp_sl_ratio = tp_sl_ratio
        self.slatr_coef = slatr_coef

    def score(self):
        # Your scoring logic here
        stat, bt = backtest(self.ticker, atr_length=self.atr_length, init_size=self.init_size , tp_sl_ratio=self.tp_sl_ratio, slatr_coef=self.slatr_coef)
        return stat["Win Rate [%]"]

# Create a grid of hyperparameters
param_grid = {
    'ticker': ["^NDX", "^SPX", "AAPL"],
    'atr_length': [1, 4, 8, 12, 16],
    'init_size': [0.02, 0.03],
    'tp_sl_ratio': [1.5, 2],
    'slatr_coef': [4, 9, 12],
}

parameters_df= []

# Iterate over all combinations
for params in ParameterGrid(param_grid):
    estimator = MyCustomEstimator(**params)
    score = estimator.score()
    # Compare scores and find the best combination
    parameters_df.append([params, score])

parameters_df
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3184709326.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] < 0 and df.MACD_HIST[row] > 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3184709326.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.MACD_HIST[row-1] > 0 and df.MACD_HIST[row] < 0
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.RSI_14MA = df.RSI
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] > 50
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]<25 and df.RSI[row-1]>25)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI[row] < 55
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3003789530.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   or (df.RSI[row]>75 and df.RSI[row-1]<75)
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3560849306.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3560849306.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.MACDSignal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3560849306.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==-1
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/3560849306.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   and df.RSI_Signal[l]==1
# [[{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   36.774193548387096],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   37.06293706293706],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   41.17647058823529],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   33.88429752066116],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   43.53741496598639],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   38.732394366197184],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   45.88235294117647],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   42.1875],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   33.734939759036145],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   27.27272727272727],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   39.37007874015748],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   34.51327433628318],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   43.07692307692308],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   38.18181818181819],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   26.923076923076923],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   24.528301886792452],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   33.6283185840708],
#  [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   35.64356435643564],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   35.58282208588957],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   35.714285714285715],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   41.66666666666667],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   33.08270676691729],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   35.714285714285715],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   33.108108108108105],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   38.095238095238095],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   35.44303797468354],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   32.69230769230769],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.95454545454545],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   33.82352941176471],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   31.092436974789916],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   36.58536585365854],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   37.878787878787875],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   33.65384615384615],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.883720930232556],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   31.092436974789916],
#  [{'atr_length': 1,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   29.591836734693878],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   34.161490683229815],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   34.69387755102041],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   39.189189189189186],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   37.2093023255814],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   36.477987421383645],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   34.72222222222222],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   34.12698412698413],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   42.42424242424242],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   43.29896907216495],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.05128205128205],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   36.52173913043478],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   34.862385321100916],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   40.816326530612244],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   31.645569620253166],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   38.2716049382716],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.91139240506329],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   35.77981651376147],
#  [{'atr_length': 4,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   36.36363636363637],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   31.952662721893493],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   32.91139240506329],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   36.30573248407643],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.78260869565217],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   29.34131736526946],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   31.125827814569533],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   28.368794326241137],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   37.83783783783784],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   40.909090909090914],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.95145631067961],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   34.146341463414636],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   28.205128205128204],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   38.18181818181819],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   39.75903614457831],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   36.0],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.04255319148936],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   29.059829059829063],
#  [{'atr_length': 4,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   35.55555555555556],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   34.33734939759036],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   32.89473684210527],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   40.0],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   41.66666666666667],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   36.41975308641975],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   32.86713286713287],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   32.55813953488372],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   34.82142857142857],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   44.89795918367347],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   33.734939759036145],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   37.5],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   34.25925925925926],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   34.82142857142857],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   34.02061855670103],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   37.07865168539326],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.91139240506329],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   35.18518518518518],
#  [{'atr_length': 8,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   40.0],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   31.213872832369944],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   29.518072289156628],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   36.708860759493675],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   35.41666666666667],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   29.411764705882355],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   30.065359477124183],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   28.671328671328673],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   29.03225806451613],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   41.81818181818181],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   36.84210526315789],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   32.30769230769231],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   29.059829059829063],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   29.03225806451613],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   31.06796116504854],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   36.0],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.608695652173914],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   29.914529914529915],
#  [{'atr_length': 8,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   32.71028037383177],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   34.54545454545455],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   31.818181818181817],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   38.25503355704698],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   39.55223880597015],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   37.423312883435585],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   33.56643356643357],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   33.59375],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   40.54054054054054],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   46.875],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   35.22727272727273],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   38.13559322033898],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   33.94495412844037],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   35.65217391304348],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   34.883720930232556],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   37.634408602150536],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.91139240506329],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   33.94495412844037],
#  [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   38.88888888888889],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   32.369942196531795],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   28.74251497005988],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   35.03184713375796],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   33.793103448275865],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   30.76923076923077],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   29.411764705882355],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   27.659574468085108],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   35.77235772357724],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   40.36697247706422],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.69387755102041],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   31.538461538461537],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   29.66101694915254],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   30.075187969924812],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   35.55555555555556],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   35.0],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.608695652173914],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   29.66101694915254],
#  [{'atr_length': 12,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   32.71028037383177],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   35.75757575757576],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   31.61290322580645],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   38.56209150326798],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   39.55223880597015],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   37.03703703703704],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   34.96503496503497],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   32.08955223880597],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   38.93805309734513],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   40.5940594059406],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   42.5],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   38.13559322033898],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   34.25925925925926],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   36.84210526315789],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   32.98969072164948],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   41.46341463414634],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   33.75],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   34.25925925925926],
#  [{'atr_length': 16,
#    'init_size': 0.02,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   40.0],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   33.33333333333333],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   27.647058823529413],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   35.625],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.02777777777778],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   30.17751479289941],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   30.32258064516129],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   28.27586206896552],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   29.770992366412212],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   40.74074074074074],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   34.69387755102041],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   30.76923076923077],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 9,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   29.914529914529915],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   29.770992366412212],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 2},
#   32.407407407407405],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   35.78947368421053],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 2},
#   32.608695652173914],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   29.914529914529915],
#  [{'atr_length': 16,
#    'init_size': 0.03,
#    'slatr_coef': 12,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 2},
#   32.71028037383177]]

# %%
# find thee param tha resulted in the highest score
# max(parameters_df, key=lambda x: x[1])

ticker_groups = {}
for item in parameters_df:
    ticker = item[0]['ticker']
    if ticker not in ticker_groups:
        ticker_groups[ticker] = []
    ticker_groups[ticker].append(item)

# Find the item with the highest value in index 1 for each ticker
result = {}
for ticker, items in ticker_groups.items():
    max_item = max(items, key=lambda x: x[1])
    result[ticker] = max_item

result
# Out:
# {'^NDX': [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^NDX',
#    'tp_sl_ratio': 1.5},
#   45.88235294117647],
#  '^SPX': [{'atr_length': 12,
#    'init_size': 0.02,
#    'slatr_coef': 9,
#    'ticker': '^SPX',
#    'tp_sl_ratio': 1.5},
#   46.875],
#  'AAPL': [{'atr_length': 1,
#    'init_size': 0.02,
#    'slatr_coef': 4,
#    'ticker': 'AAPL',
#    'tp_sl_ratio': 1.5},
#   43.53741496598639]}

# %%
stat, bt = backtest("^SPX", atr_length=12, init_size=0.02 , tp_sl_ratio=1.5, slatr_coef=9)
bt.plot()
stat
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/805540974.py:2: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   bt.plot()
# Start                     2021-06-07 09:30:00
# End                       2024-03-25 13:30:00
# Duration                   1022 days 04:00:00
# Exposure Time [%]                   83.736532
# Equity Final [$]                383124.781298
# Equity Peak [$]                 396626.663622
# Return [%]                         283.124781
# Buy & Hold Return [%]               23.857585
# Return (Ann.) [%]                   61.626701
# Volatility (Ann.) [%]               74.798532
# Sharpe Ratio                         0.823903
# Sortino Ratio                        2.169562
# Calmar Ratio                         2.103778
# Max. Drawdown [%]                  -29.293348
# Avg. Drawdown [%]                   -3.422546
# Max. Drawdown Duration      338 days 01:00:00
# Avg. Drawdown Duration       10 days 12:00:00
# # Trades                                   96
# Win Rate [%]                           46.875
# Best Trade [%]                       9.191412
# Worst Trade [%]                      -3.24026
# Avg. Trade [%]                       1.088293
# Max. Trade Duration          77 days 23:00:00
# Avg. Trade Duration          16 days 18:00:00
# Profit Factor                         2.67194
# Expectancy [%]                       1.137158
# SQN                                  3.376273
# Kelly Criterion                      0.307961
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
stat, bt = backtest("^NDX", atr_length=1, init_size=0.02 , tp_sl_ratio=1.5, slatr_coef=9)
bt.plot()
stat
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/2712909604.py:2: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   bt.plot()
# Start                     2021-04-30 09:30:00
# End                       2024-03-25 14:30:00
# Duration                   1060 days 05:00:00
# Exposure Time [%]                   83.798663
# Equity Final [$]                787306.205566
# Equity Peak [$]                  804194.38916
# Return [%]                         687.306206
# Buy & Hold Return [%]               31.297349
# Return (Ann.) [%]                  104.069481
# Volatility (Ann.) [%]              139.473377
# Sharpe Ratio                          0.74616
# Sortino Ratio                         2.65348
# Calmar Ratio                         2.194274
# Max. Drawdown [%]                  -47.427741
# Avg. Drawdown [%]                   -3.874711
# Max. Drawdown Duration      323 days 00:00:00
# Avg. Drawdown Duration        8 days 15:00:00
# # Trades                                   85
# Win Rate [%]                        45.882353
# Best Trade [%]                       21.26462
# Worst Trade [%]                     -9.698482
# Avg. Trade [%]                       1.537092
# Max. Trade Duration         231 days 00:00:00
# Avg. Trade Duration          21 days 17:00:00
# Profit Factor                        2.574644
# Expectancy [%]                       1.684109
# SQN                                  2.739012
# Kelly Criterion                      0.304155
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %% [markdown]
# ## Higheest return

# %%
stat2, bt2 = backtest("^NDX", atr_length=1, init_size=0.02 , tp_sl_ratio=2, slatr_coef=4)
bt.plot(show_legend=False)
stat2
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/41808923.py:2: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   bt.plot(show_legend=False)
# Start                     2021-04-30 09:30:00
# End                       2024-03-25 13:30:00
# Duration                   1060 days 04:00:00
# Exposure Time [%]                    69.79351
# Equity Final [$]                535038.649414
# Equity Peak [$]                 692238.485352
# Return [%]                         435.038649
# Buy & Hold Return [%]               31.331815
# Return (Ann.) [%]                    78.56135
# Volatility (Ann.) [%]                90.42001
# Sharpe Ratio                         0.868849
# Sortino Ratio                        2.772082
# Calmar Ratio                         2.580232
# Max. Drawdown [%]                  -30.447395
# Avg. Drawdown [%]                    -2.86957
# Max. Drawdown Duration      266 days 02:00:00
# Avg. Drawdown Duration        8 days 12:00:00
# # Trades                                  143
# Win Rate [%]                        37.062937
# Best Trade [%]                      13.674375
# Worst Trade [%]                     -4.340308
# Avg. Trade [%]                       0.795216
# Max. Trade Duration          97 days 23:00:00
# Avg. Trade Duration           8 days 03:00:00
# Profit Factor                        2.069664
# Expectancy [%]                       0.854606
# SQN                                  1.696014
# Kelly Criterion                      0.126982
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %%
stat, bt = backtest("^NDX", atr_length=1, init_size=0.03 , tp_sl_ratio=1.5, slatr_coef=9)
bt.plot()
stat
# Out:
# /var/folders/mb/tyl8xvh9689bgk14qr31lc7r0000gn/T/ipykernel_9219/519562990.py:2: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   bt.plot()
# Start                     2021-04-30 09:30:00
# End                       2024-03-25 14:30:00
# Duration                   1060 days 05:00:00
# Exposure Time [%]                   77.349587
# Equity Final [$]               1701710.500977
# Equity Peak [$]                1750078.258789
# Return [%]                        1601.710501
# Buy & Hold Return [%]               31.297349
# Return (Ann.) [%]                  166.373702
# Volatility (Ann.) [%]              244.905113
# Sharpe Ratio                         0.679339
# Sortino Ratio                        3.474715
# Calmar Ratio                         3.553907
# Max. Drawdown [%]                  -46.814307
# Avg. Drawdown [%]                   -5.892652
# Max. Drawdown Duration      262 days 00:00:00
# Avg. Drawdown Duration        9 days 06:00:00
# # Trades                                  105
# Win Rate [%]                        38.095238
# Best Trade [%]                       21.26462
# Worst Trade [%]                      -5.53113
# Avg. Trade [%]                       1.232891
# Max. Trade Duration         170 days 23:00:00
# Avg. Trade Duration          15 days 09:00:00
# Profit Factor                        2.478792
# Expectancy [%]                       1.347509
# SQN                                  2.463081
# Kelly Criterion                      0.240695
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
